# %% [markdown]
# <a href="https://colab.research.google.com/github/Hubert1234567890/python_data_science-/blob/main/pandas/pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
country=['india','srilanka','china','usa','brazil'] #square braces
pd.Series(country)
# Out:
# 0       india
# 1    srilanka
# 2       china
# 3         usa
# 4      brazil
# dtype: object

# %%
scores =[30,89,56,45]
pd.Series(scores)
# Out:
# 0    30
# 1    89
# 2    56
# 3    45
# dtype: int64

# %%
## custom indexing
subject=['maths','english','hindi','science']
marks=[56,78,97,67]
marks_series= pd.Series(marks,index = subject,name = 'shivam  marks') ## we just use a keyword index
marks_series
# Out:
# maths      56
# english    78
# hindi      97
# science    67
# Name: shivam  marks, dtype: int64

# %%
## series from dictionary
marks={
    'maths' :98,
    'science':89,
    'english': 93
}
shivam_marks =pd.Series(marks,name='shivam ke marks')
shivam_marks
# Out:
# maths      98
# science    89
# english    93
# Name: shivam ke marks, dtype: int64

# %% [markdown]
# attributes of Series

# %%
## size
shivam_marks.size
# Out:
# 3

# %%
## dtype
shivam_marks.dtype
# Out:
# dtype('int64')

# %%
## name attribute (name of a series is its attribute )
shivam_marks.name
# Out:
# 'shivam ke marks'

# %%
## is_unique
shivam_marks.is_unique
# Out:
# True

# %%
## index
print(shivam_marks.index)
## values
print(shivam_marks.values)
# Out:
# Index(['maths', 'science', 'english'], dtype='object')
# [98 89 93]

# %%
##reading csv files
import pandas as pd
import numpy as np
subs = pd.read_csv('/content/subs.csv')

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col= 'match_no')#index_col indicates which
##column will be used as the index

# %%
movies= pd.read_csv('/content/bollywood.csv')
movies
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
movies.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
movies.tail()
# Out:
#                        movie              lead
# 1495  Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496     Aankhen (2002 film)  Amitabh Bachchan
# 1497         Saathiya (film)      Vivek Oberoi
# 1498          Company (film)        Ajay Devgn
# 1499    Awara Paagal Deewana      Akshay Kumar

# %%
movies.sample(5)
# Out:
#               movie              lead
# 132        Pataakha    Sanya Malhotra
# 360          ABCD 2       Prabhu Deva
# 773     Bheja Fry 2      Vinay Pathak
# 529   Finding Fanny  Deepika Padukone
# 1090   Fool & Final     Shahid Kapoor

# %%
movie_series= movies["movie"]
movie_series
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1495                  Hum Tumhare Hain Sanam
# 1496                     Aankhen (2002 film)
# 1497                         Saathiya (film)
# 1498                          Company (film)
# 1499                    Awara Paagal Deewana
# Name: movie, Length: 1500, dtype: object

# %%
lead_series=movies["lead"]
lead_series
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1495      Shah Rukh Khan
# 1496    Amitabh Bachchan
# 1497        Vivek Oberoi
# 1498          Ajay Devgn
# 1499        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
lead_series.value_counts()# its value_counts not value count  and it lists the values in descending order
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
vk.value_counts()## this tells me the runs scroed in matches like 0 is scored in 9 matches
# Out:
# runs
# 0       9
# 1       8
# 12      8
# 9       7
# 8       6
#        ..
# 92      1
# 99      1
# 108     1
# 109     1
# 113     1
# Name: count, Length: 78, dtype: int64

# %%
vk_runs=vk["runs"]
print(vk_runs.sort_values(ascending=False).head(1).values[0])
# Out:
# 113

# %%
movies.sort_values(by="movie")
movies.sort_values(by="lead")
# Out:
#                                  movie          lead
# 217                         Qaidi Band    Aadar Jain
# 553     Roar: Tigers of the Sundarbans  Aadil Chahal
# 205           Lipstick Under My Burkha  Aahana Kumra
# 974               Raat Gayi Baat Gayi?  Aamir Bashir
# 729    Talaash: The Answer Lies Within    Aamir Khan
# ...                                ...           ...
# 306                Dil Toh Deewana Hai   Zeenat Aman
# 257                    Sallu Ki Shaadi   Zeenat Aman
# 458                 Strings of Passion   Zeenat Aman
# 911           Dunno Y... Na Jaane Kyon   Zeenat Aman
# 1305  Taj Mahal: An Eternal Love Story   Zulfi Sayed
#
# [1500 rows x 2 columns]

# %%
movies[["movie"]]
# Out:
#                                      movie
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1495                Hum Tumhare Hain Sanam
# 1496                   Aankhen (2002 film)
# 1497                       Saathiya (film)
# 1498                        Company (film)
# 1499                  Awara Paagal Deewana
#
# [1500 rows x 1 columns]

# %%
vk_runs.describe() ### gives all the summary about the data
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
x = pd.Series([21,56,43,59,67,34,65,32,45,64,64,34,87])
x
# Out:
# 0     21
# 1     56
# 2     43
# 3     59
# 4     67
# 5     34
# 6     65
# 7     32
# 8     45
# 9     64
# 10    64
# 11    34
# 12    87
# dtype: int64

# %%
x.iloc[-1]
x.loc[1]
x.loc[[0,4,7]]=[45,9,67]
x
# Out:
# 0     45
# 1     56
# 2     43
# 3     59
# 4      9
# 5     34
# 6     65
# 7     67
# 8     45
# 9     64
# 10    64
# 11    34
# 12    87
# dtype: int64

# %%
list(x) ## packs all the values  of the series in that list
# Out:
# [45, 56, 43, 59, 9, 34, 65, 67, 45, 64, 64, 34, 87]

# %%
print(dict(x))
# Out:
# {0: np.int64(45), 1: np.int64(56), 2: np.int64(43), 3: np.int64(59), 4: np.int64(9), 5: np.int64(34), 6: np.int64(65), 7: np.int64(67), 8: np.int64(45), 9: np.int64(64), 10: np.int64(64), 11: np.int64(34), 12: np.int64(87)}

# %%
100 - marks_series   ##
# Out:
# maths      44
# english    22
# hindi       3
# science    33
# Name: shivam  marks, dtype: int64

# %%
vk[vk_runs > 50].size   ## here what i have used is boolean indexing and
# Out:
# 48

# %%
vk[vk_runs == 0].size
# Out:
# 9

# %%
actor = lead_series.value_counts()
print(actor[actor > 20])
print(actor[actor>20].size)
## the problem was to find the number of actors who have made more than 20 movies
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64
# 7

# %%
subscribers = subs["Subscribers gained"]
subscribers.head(30).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
vk_runs.head(20).plot(kind= 'bar')
# Out:
# <Axes: xlabel='match_no'>

# %%
actor.head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
